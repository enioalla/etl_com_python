# %%
#Importando Dataframe com ranking de venda de jogos mundialmente

import pandas as pd


df = pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Utilizando apenas os jogos da plataforma "Wii" e 
# com venda mundial superior ou igual 1.0

df['Platform'].unique()

var1 = df.loc[(df['Platform'] == "Wii") & (df['Global_Sales'] >= 1.0)]

#Eliminando o rank geral dos jogos

df_sem_rank = var1.drop('Rank', axis = 1)
df_sem_rank.head()
# Out:
#                         Name Platform    Year     Genre Publisher  NA_Sales  \
# 0                 Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 2             Mario Kart Wii      Wii  2008.0    Racing  Nintendo     15.85
# 3          Wii Sports Resort      Wii  2009.0    Sports  Nintendo     15.75
# 7                   Wii Play      Wii  2006.0      Misc  Nintendo     14.03
# 8  New Super Mario Bros. Wii      Wii  2009.0  Platform  Nintendo     14.59
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 7      9.20      2.93         2.85         29.02
# 8      7.06      4.70         2.26         28.62

# %%
#Classificando o rank dos jogos filtrados apenas
rows = len(var1_sem_rank.index)
n = 1
while n <= rows:
    rank.append(n)
    n +=1
rank = list(set(rank))

df_sem_rank.insert(0,"Rank", rank)

df_novo_rank = df_sem_rank

# %%
df_novo_rank.head()
# Out:
#    Rank                       Name Platform    Year     Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0    Sports  Nintendo
# 2     2             Mario Kart Wii      Wii  2008.0    Racing  Nintendo
# 3     3          Wii Sports Resort      Wii  2009.0    Sports  Nintendo
# 7     4                   Wii Play      Wii  2006.0      Misc  Nintendo
# 8     5  New Super Mario Bros. Wii      Wii  2009.0  Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62

# %%
#Criando novo arquivo csv com o conteúdo do novo dataframe

df_novo_rank = pd.DataFrame(df_novo_rank)
df_novo_rank.to_csv('vendas_wii.csv')
